# %% [markdown]
# For Q2, we will attempt to classify if the job is data science related using only the job description feature.
#
# The data will first be labelled with some keywords in the job title column.

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.feature_extraction.text import TfidfVectorizer
from collections import Counter

# %matplotlib inline

# %%
jobs = pd.read_pickle('jobs2.pkl')
jobs
# Out:
#                                               job_title  \
# 0                                          Product Lead
# 1                                       Product Manager
# 2                   Regional Marketing Manager  GC GCMS
# 3                 Regional Product Specialist Insurance
# 4                       Interchange and Pricing Analyst
# 5                                 VP  Data Analyst  GTO
# 6                                      Desktop Engineer
# 7     Consultant Senior Consultant  Banking Business...
# 8                                 R&D Programme Manager
# 9     Associate Specialist  Cybersecurity DSP  CLT  ...
# 10    Technical Lead  IT Client Information  Associa...
# 11                                       Data Scientist
# 12                                    Technical Analyst
# 13    Associate Medical Account Executive  Diabetics...
# 14                         Engineer  Snr Engineer  IPTV
# 15    Threat Analyst  Research Operations   Business...
# 16    Senior Director   Head of Business Solutions  ...
# 17    Human Resources  Corporate Functions Recruitme...
# 18    Consultant Insurance Industry Junior level  Bu...
# 19    Operations Program Manager   Network Performan...
# 20                     PM: Intelligent Mapping Services
# 21                            Regional Offshore Manager
# 22    Software Engineer  IBM Center for Blockchain I...
# 23                                       System Analyst
# 24    Data Scientist  ML  Python coding    perm in B...
# 25                      Product Analytics Manager  GBI
# 26     Product Marketing Manager  Advertising Solutions
# 27    VP APAC Business Development  Operations and S...
# 28                                  Production Engineer
# 29                                      Product Analyst
# ...                                                 ...
# 2984                                   Business Analyst
# 2985                                     Supply Planner
# 2986                Solutions Architect   Deep learning
# 2987  Data Scientist   Data Analyst  Manager  – Digi...
# 2988               Exhibition Sales Executive   Manager
# 2989            Engineering Manager   API Platform team
# 2990                                     Data Scientist
# 2991      Associate Director  FCC Controls   Governance
# 2992                      Director of Digital Analytics
# 2993                          T  – Technical Consultant
# 2994                                   Back up Engineer
# 2995                                           IT Admin
# 2996                                 Process Technician
# 2997                Senior Advisor  Risk Data Modelling
# 2998            Research Engineer: Solar Energy Systems
# 2999                              Murex Project Manager
# 3000                         Business Analyst  Pricing
# 3001                                 Research Associate
# 3002                                           Engineer
# 3003                                      Engineer MEMS
# 3004                     Project Manager  Applications
# 3005                            APAC CRM & Data Manager
# 3006                         Senior Sales Manager  MICE
# 3007                            Business Analyst  APACx
# 3008                          SYSTEMS ANALYST  DIGITAL
# 3009                             Sales Business Officer
# 3010               Airline Business Solution Consultant
# 3011                  Senior Data Scientist  Singapore
# 3012                         Technical Sales Specialist
# 3013                         TPCE PEEI Process Engineer
#
#                                                 company  \
# 0                                           unavailable
# 1                                                 99.co
# 2                              Thermo Fisher Scientific
# 3                                           unavailable
# 4                                                 Adyen
# 5                                  United Overseas Bank
# 6                                           unavailable
# 7                                              Synpulse
# 8      ST Electronics (Satcom & Sensor Systems) Pte Ltd
# 9                                                   MSD
# 10                                    Bank of Singapore
# 11                               Asia Fusion Technology
# 12                NTT DATA Business Solutions Singapore
# 13                                                  MSD
# 14                                              StarHub
# 15                                             Facebook
# 16                                                 Visa
# 17                                      JP Morgan Chase
# 18                                                  RGF
# 19                                             Facebook
# 20                                               WeWork
# 21                                          unavailable
# 22                                                  IBM
# 23    Centre for Strategic Infocomm Technologies (CSIT)
# 24                              David & Goliath Pte Ltd
# 25                                               Oracle
# 26                                               Appier
# 27                                          TripAdvisor
# 28                                      TRUSSCO PTE LTD
# 29                              New Step Search Pte Ltd
# ...                                                 ...
# 2984                                         M1 Limited
# 2985                                         ExxonMobil
# 2986                                             NVIDIA
# 2987                                TRIBE GLOBAL SEARCH
# 2988                               Spire Events Pte Ltd
# 2989                                          Grab Taxi
# 2990                                                 HP
# 2991                                        unavailable
# 2992                           Chris Consulting Pte Ltd
# 2993                                          Cognizant
# 2994                                              Agoda
# 2995                              ST Recruitment Centre
# 2996                                              Dyson
# 2997                                                FIS
# 2998       Solar Energy Research Institute of Singapore
# 2999                                            Sciente
# 3000                                           Manpower
# 3001                                        unavailable
# 3002                          Forum Energy Technologies
# 3003                                    GLOBALFOUNDRIES
# 3004                                            Sciente
# 3005                                       Michael Page
# 3006        Fairmont Singapore & Swissôtel The Stamford
# 3007                                               Uber
# 3008                                        unavailable
# 3009                  POWER INDUSTRIES SERVICES Pte Ltd
# 3010                                        unavailable
# 3011                                          Aspire HK
# 3012                           Thermo Fisher Scientific
# 3013                                              Apple
#
#                        location  \
# 0            Tiong Bahru Estate
# 1                     Singapore
# 2                     Woodlands
# 3                        Outram
# 4                     Singapore
# 5                     Singapore
# 6                     Singapore
# 7                     Singapore
# 8                     Singapore
# 9                     Singapore
# 10                    Singapore
# 11                    Singapore
# 12              Bishan New Town
# 13                    Singapore
# 14                   Queenstown
# 15                    Singapore
# 16                    Singapore
# 17                    Singapore
# 18                    Singapore
# 19                    Singapore
# 20                    Singapore
# 21                     Clementi
# 22            Central Singapore
# 23                    Singapore
# 24                    Singapore
# 25                       Outram
# 26                    Singapore
# 27                    Singapore
# 28                   Ang Mo Kio
# 29    Central Business District
# ...                         ...
# 2984                     Jurong
# 2985                  Singapore
# 2986                  Singapore
# 2987                  Singapore
# 2988              Tanjong Pagar
# 2989                  Singapore
# 2990                  Singapore
# 2991                  Singapore
# 2992                  Singapore
# 2993                  Singapore
# 2994                  Singapore
# 2995                Jurong East
# 2996                  Singapore
# 2997                  Singapore
# 2998                 Queenstown
# 2999                  Singapore
# 3000                  Singapore
# 3001                     Jurong
# 3002                  Singapore
# 3003                   Tampines
# 3004                  Singapore
# 3005                  Singapore
# 3006                  Singapore
# 3007                  Singapore
# 3008                     Outram
# 3009                  Singapore
# 3010                  Pasir Ris
# 3011                  Singapore
# 3012                  Woodlands
# 3013                  Toa Payoh
#
#                                                job_desc  full_time  part_time  \
# 0     Mission:   Your mission is to build a world cl...          0          0
# 1     99.co is looking for an experienced Product Ma...          0          0
# 2     Job Description Job Title: Regional Marketing ...          0          0
# 3     The Job:   Reporting directly to the Regional ...          1          0
# 4     Adyen is looking for a Interchange & Pricing A...          0          0
# 5     Functional area: Business Technology Services ...          0          0
# 6     Be a ‘roaming’ engineer, moving to and coverin...          1          0
# 7     Responsibilities:  Conduct research, data coll...          0          0
# 8     Job Responsibilities: Project planning, manage...          0          0
# 9     The trainee will  undergo a 9 - 12-month progr...          0          0
# 10    Salary: Competitive  Singapore  Job Type: Perm...          1          0
# 11    You will play a key role in the data analytic ...          0          0
# 12    As the leading analytics provider in APAC and ...          0          0
# 13    Detail, promote and sell MSD’s products to doc...          0          0
# 14    Engineer/ Snr Engineer, IPTV - (16000079) Desc...          0          0
# 15    (Singapore) Facebook's mission is to give peop...          0          0
# 16    Job Description  Responsible for leading all m...          0          0
# 17    This high profile specialist role will focus o...          0          0
# 18    Roles  Engage in business improvement and/or I...          0          0
# 19    (Singapore) Facebook's mission is to give peop...          0          0
# 20    We are looking for a motivated, thorough, expe...          0          0
# 21    DNV GL is the world’s leading classification s...          1          0
# 22    Job Description IBM Research is seeking highly...          0          0
# 23    Develop solutions for data management, data an...          0          0
# 24    We are looking for gamechangers who are famili...          1          0
# 25    The Global Business Intelligence team is a key...          1          0
# 26    Regional Product Marketing Manager, Advertisin...          0          0
# 27    TripAdvisor is seeking a unique individual to ...          0          0
# 28    The Production Supervisor manages production o...          1          0
# 29    Job SummaryOur client is an innovative Singapo...          1          0
# ...                                                 ...        ...        ...
# 2984  Job ID:  MKT-BA-MSP-4   Job Type:  Full Time  ...          0          0
# 2985  Responsibilities:  • Lead cross functional tea...          0          0
# 2986  We are now looking for a Senior Solutions Arch...          0          0
# 2987  Job SummaryData Scientist / Data Analyst (Mana...          1          0
# 2988  The Exhibition Sales Executive / Manager is re...          0          0
# 2989  Get to know our Team:   Come join the team tha...          0          0
# 2990  HP is a proven leader in personal systems and ...          0          0
# 2991  Business (Responsibilities related to the deli...          0          0
# 2992  Accountable for leading a team of Digital Anal...          0          0
# 2993  Job Summary: -   Experience: -8 to 12 Yrs   Wo...          0          0
# 2994  We are looking for a Backup engineer to work o...          1          0
# 2995  FULL-TIME/IT ADMIN (CUSTOMER SUPPORT)   IMMEDI...          1          0
# 2996  We are looking for an experienced Process Tech...          0          0
# 2997  Responsibilities  Building and implementing th...          0          0
# 2998  SERIS Department : Solar Energy Systems (SES) ...          0          0
# 2999  Seeking a meticulous and drivenÂ ProjectÂ Mana...          0          0
# 3000  - Work closely with business users, external v...          1          0
# 3001  Data Scientist / Programmer for Regional ATM M...          0          0
# 3002  Job Description:Purpose: Assist in the design ...          0          0
# 3003  Responsibilities:  Work with a cross functiona...          0          0
# 3004  Seeking a meticulous and driven Project Manage...          0          0
# 3005  Regional role  Permanent role  About Our Clien...          1          0
# 3006  Senior/Sales Manager, MICE  Primary Location :...          0          0
# 3007  About Uber We’re changing the way people think...          0          0
# 3008  Convertium is one of Singapore's most establis...          0          0
# 3009  The position shall be responsible Meeting regu...          1          0
# 3010  PURPOSE   Achieve the strategic, financial and...          0          0
# 3011  Time to work with Kaggle champs and an award-w...          1          0
# 3012  Job Description  Responsible to provide techni...          0          0
# 3013  Job Description:   As a Backend End Central Te...          1          0
#
#       temporary  internship  contract  permanent  salary
# 0             0           0         0          0     NaN
# 1             0           0         0          0  7800.0
# 2             0           0         0          0     NaN
# 3             0           0         0          1     NaN
# 4             0           0         0          0     NaN
# 5             0           0         0          0     NaN
# 6             0           0         0          1     NaN
# 7             0           0         0          0     NaN
# 8             0           0         0          0     NaN
# 9             0           0         0          0     NaN
# 10            0           0         0          1     NaN
# 11            0           0         0          0     NaN
# 12            0           0         0          0     NaN
# 13            0           0         0          0     NaN
# 14            0           0         0          0     NaN
# 15            0           0         0          0     NaN
# 16            0           0         0          0     NaN
# 17            0           0         0          0     NaN
# 18            0           0         0          0     NaN
# 19            0           0         0          0     NaN
# 20            0           0         0          0     NaN
# 21            0           0         0          1     NaN
# 22            0           0         0          0     NaN
# 23            0           0         0          0     NaN
# 24            0           0         0          1     NaN
# 25            0           0         0          1     NaN
# 26            0           0         0          0     NaN
# 27            0           0         0          0     NaN
# 28            0           0         0          1     NaN
# 29            0           0         0          1  7000.0
# ...         ...         ...       ...        ...     ...
# 2984          0           0         0          0     NaN
# 2985          0           0         0          0     NaN
# 2986          0           0         0          0     NaN
# 2987          0           0         0          1     NaN
# 2988          0           0         0          0     NaN
# 2989          0           0         0          0     NaN
# 2990          0           0         0          0     NaN
# 2991          0           0         0          0     NaN
# 2992          0           0         0          0     NaN
# 2993          0           0         0          0     NaN
# 2994          0           0         0          1     NaN
# 2995          0           0         0          1     NaN
# 2996          0           0         0          0     NaN
# 2997          0           0         0          0     NaN
# 2998          0           0         0          0     NaN
# 2999          0           0         0          0     NaN
# 3000          0           0         0          1     NaN
# 3001          0           0         1          0     NaN
# 3002          0           0         0          0     NaN
# 3003          0           0         0          0     NaN
# 3004          0           0         0          0     NaN
# 3005          0           0         0          1     NaN
# 3006          0           0         0          0     NaN
# 3007          0           0         0          0     NaN
# 3008          0           0         0          0     NaN
# 3009          0           0         0          1     NaN
# 3010          0           0         0          0     NaN
# 3011          0           0         0          1     NaN
# 3012          0           0         0          0     NaN
# 3013          0           0         0          1     NaN
#
# [3014 rows x 11 columns]

# %%
jobs['datascience_job'] = 0

# %%
# Using the job title lets label whether our data is a data science related job
for idx, title in zip(jobs['job_title'].index, jobs['job_title'].values):
    if 'data' in title.lower() and 'analyst' in  title.lower():
        jobs.iat[idx, -1] = 1
    elif 'data' in title.lower() and 'scientist' in  title.lower():
        jobs.iat[idx, -1] = 1
    elif 'data' in title.lower() and 'engineer' in  title.lower():
        jobs.iat[idx, -1] = 1
    elif 'business' in title.lower() and 'analyst' in  title.lower():
        jobs.iat[idx, -1] = 1
    elif 'business' in title.lower() and 'intelligence' in  title.lower():
        jobs.iat[idx, -1] = 1
    elif 'machine learning' in title.lower() or 'deep learning' in title.lower() or 'ml' in title.lower():
        jobs.iat[idx, -1] = 1
    elif 'artificial intelligence' in title.lower() or 'ai' in title.lower():
        jobs.iat[idx, -1] = 1
    else:
        jobs.iat[idx, -1] = 0

# %%
jobs['datascience_job'].value_counts()
# Out:
# 0    2160
# 1     854
# Name: datascience_job, dtype: int64

# %%
pd.to_pickle(jobs, 'jobs_ds')

# %%
X = jobs.loc[:, 'job_desc']
y = jobs.loc[:, 'datascience_job']

# %%
# Using the textacy package to do some more comprehensive preprocessing
from textacy.preprocess import preprocess_text

clean_jd = [preprocess_text(desc, fix_unicode=True, lowercase=True, transliterate=False,
                              no_urls=True, no_emails=True, no_phone_numbers=True, no_currency_symbols=True,
                              no_punct=True, no_accents=True)
              for desc in X]

# %%
# Preprocess our text data to Tfidf
tfv = TfidfVectorizer(ngram_range=(1,4), max_features=2500)
X_jd = tfv.fit_transform(clean_jd).toarray()
X_dfjd = pd.DataFrame(X_jd, columns=tfv.get_feature_names())
print(X_dfjd.shape)
# Out:
# (3014, 2500)

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X_dfjd, y, test_size = 0.25)

# %%
# majority class is 0
base_accuracy = 1 - y.mean()
print('Base Accuracy Score: ' + str(base_accuracy))
# Out:
# Base Accuracy Score: 0.7166556071665561

# %%
# Running Logistic Regression to classify test set:
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

logreg = LogisticRegression()
logreg.fit(X_train, y_train)

y_pred = logreg.predict(X_test)

print('Accuracy Score: ' + str(logreg.score(X_test, y_test)))
print('=============================================================')
print('Classification Report:')
print(classification_report(y_test, y_pred))
print('=============================================================')
print('Confusion Matrix:')
print(pd.DataFrame(confusion_matrix(y_test, y_pred)))
# Out:
# Accuracy Score: 0.809018567639
# =============================================================
# Classification Report:
#              precision    recall  f1-score   support
#
#           0       0.81      0.95      0.87       524
#           1       0.82      0.48      0.60       230
#
# avg / total       0.81      0.81      0.79       754
#
# =============================================================
# Confusion Matrix:
#      0    1
# 0  500   24
# 1  120  110

# %%
# Running Random forest with gridsearch to classify test set:
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

param_grid = { 
           "n_estimators" : range(1,40,1),
           "max_depth" : range(1,40,1),
}

rfc = GridSearchCV(RandomForestClassifier(), param_grid, cv=5, verbose=1, n_jobs=3, scoring='f1')
rfc.fit(X_train, y_train)

best_rfc = rfc.best_estimator_
print('Best Parameters: ' + str(rfc.best_params_))
print('=============================================================')
print('Best Accuracy Score: ' + str(rfc.best_score_))
print('=============================================================')
print('Classification Report:')
print(classification_report(y_test, rfc.predict(X_test)))
print('=============================================================')
print('Confusion Matrix:')
print(pd.DataFrame(confusion_matrix(y_test, rfc.predict(X_test))))
# Out:
# Fitting 5 folds for each of 1521 candidates, totalling 7605 fits
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:   15.6s
# [Parallel(n_jobs=3)]: Done 194 tasks      | elapsed:   28.5s
# [Parallel(n_jobs=3)]: Done 444 tasks      | elapsed:   50.0s
# [Parallel(n_jobs=3)]: Done 794 tasks      | elapsed:  1.4min
# [Parallel(n_jobs=3)]: Done 1244 tasks      | elapsed:  2.2min
# [Parallel(n_jobs=3)]: Done 1794 tasks      | elapsed:  3.4min
# [Parallel(n_jobs=3)]: Done 2444 tasks      | elapsed:  5.1min
# [Parallel(n_jobs=3)]: Done 3194 tasks      | elapsed:  7.2min
# [Parallel(n_jobs=3)]: Done 4044 tasks      | elapsed:  9.9min
# [Parallel(n_jobs=3)]: Done 4994 tasks      | elapsed: 13.3min
# [Parallel(n_jobs=3)]: Done 6044 tasks      | elapsed: 17.5min
# [Parallel(n_jobs=3)]: Done 7194 tasks      | elapsed: 22.3min
# [Parallel(n_jobs=3)]: Done 7605 out of 7605 | elapsed: 24.2min finished
# Best Parameters: {'max_depth': 37, 'n_estimators': 38}
# =============================================================
# Best Accuracy Score: 0.644860752215
# =============================================================
# Classification Report:
#              precision    recall  f1-score   support
#
#           0       0.81      0.96      0.88       532
#           1       0.83      0.45      0.58       222
#
# avg / total       0.82      0.81      0.79       754
#
# =============================================================
# Confusion Matrix:
#      0    1
# 0  512   20
# 1  122  100

# %% [markdown]
# ## Handling the imbalance in class labels
#
# ### Undersampling the majority class

# %%
from imblearn.under_sampling import RandomUnderSampler

rus = RandomUnderSampler(ratio='majority', random_state=1)
X_train_rus, y_train_rus = rus.fit_sample(X_train, y_train)

print("Distribution of class labels before resampling {}".format(Counter(y_train)))
print("Distribution of class labels after resampling {}".format(Counter(y_train_rus)))
# Out:
# Distribution of class labels before resampling Counter({0: 1636, 1: 624})
# Distribution of class labels after resampling Counter({0: 624, 1: 624})

# %%
# Running Logistic Regression to classify test set:
from sklearn.linear_model import LogisticRegression
from sklearn.metrics import classification_report, confusion_matrix

logreg = LogisticRegression()
logreg.fit(X_train_rus,  y_train_rus)

y_pred = logreg.predict(X_test)

print('Accuracy Score: ' + str(logreg.score(X_test, y_test)))
print('=============================================================')
print('Classification Report:')
print(classification_report(y_test, y_pred))
print('=============================================================')
print('Confusion Matrix:')
print(pd.DataFrame(confusion_matrix(y_test, y_pred)))
# Out:
# Accuracy Score: 0.831564986737
# =============================================================
# Classification Report:
#              precision    recall  f1-score   support
#
#           0       0.91      0.84      0.87       524
#           1       0.69      0.81      0.75       230
#
# avg / total       0.84      0.83      0.84       754
#
# =============================================================
# Confusion Matrix:
#      0    1
# 0  440   84
# 1   43  187

# %%
# Running Random forest with gridsearch to classify test set:
from sklearn.ensemble import RandomForestClassifier
from sklearn.model_selection import GridSearchCV

param_grid = { 
           "n_estimators" : range(1,40,1),
           "max_depth" : range(1,40,1),
}

rfc = GridSearchCV(RandomForestClassifier(), param_grid, cv=5, verbose=1, n_jobs=3, scoring='f1')
rfc.fit(X_train_rus, y_train_rus)

best_rfc = rfc.best_estimator_
print('Best Parameters: ' + str(rfc.best_params_))
print('=============================================================')
print('Best Accuracy Score: ' + str(rfc.best_score_))
print('=============================================================')
print('Classification Report:')
print(classification_report(y_test, rfc.predict(X_test)))
print('=============================================================')
print('Confusion Matrix:')
print(pd.DataFrame(confusion_matrix(y_test, rfc.predict(X_test))))
# Out:
# Fitting 5 folds for each of 1521 candidates, totalling 7605 fits
# [Parallel(n_jobs=3)]: Done  44 tasks      | elapsed:    3.1s
# [Parallel(n_jobs=3)]: Done 194 tasks      | elapsed:   11.5s
# [Parallel(n_jobs=3)]: Done 444 tasks      | elapsed:   25.7s
# [Parallel(n_jobs=3)]: Done 794 tasks      | elapsed:   49.6s
# [Parallel(n_jobs=3)]: Done 1244 tasks      | elapsed:  1.3min
# [Parallel(n_jobs=3)]: Done 1794 tasks      | elapsed:  2.1min
# [Parallel(n_jobs=3)]: Done 2444 tasks      | elapsed:  3.1min
# [Parallel(n_jobs=3)]: Done 3194 tasks      | elapsed:  4.3min
# [Parallel(n_jobs=3)]: Done 4044 tasks      | elapsed:  5.8min
# [Parallel(n_jobs=3)]: Done 4994 tasks      | elapsed:  7.4min
# [Parallel(n_jobs=3)]: Done 6044 tasks      | elapsed:  9.3min
# [Parallel(n_jobs=3)]: Done 7194 tasks      | elapsed: 11.4min
# [Parallel(n_jobs=3)]: Done 7605 out of 7605 | elapsed: 12.2min finished
# Best Parameters: {'max_depth': 22, 'n_estimators': 38}
# =============================================================
# Best Accuracy Score: 0.782913449934
# =============================================================
# Classification Report:
#              precision    recall  f1-score   support
#
#           0       0.90      0.78      0.84       524
#           1       0.62      0.80      0.69       230
#
# avg / total       0.81      0.79      0.79       754
#
# =============================================================
# Confusion Matrix:
#      0    1
# 0  410  114
# 1   47  183

# %% [markdown]
# A better accuracy score than baseline is achieved for both logistic regression and random forest after undersampling the majority class.
#
# Logistic regression seems to be the better model for predicting. It achieved better results for all the metrics being considered.
